# %% [markdown]
# # Aura Setup & Installation
#
# Run this notebook first to install all dependencies.

# %%
# Install all required packages
# %pip install pandas>=2.0 numpy>=1.24 scikit-learn>=1.3 xgboost>=2.0 lightgbm>=4.0 shap>=0.43 matplotlib>=3.7 seaborn>=0.12 plotly>=5.15 pyarrow openpyxl tqdm pyyaml joblib ipywidgets --quiet

print('All packages installed successfully!')

# %%
# Verify imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import shap
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_auc_score, classification_report

print(f'pandas: {pd.__version__}')
print(f'numpy: {np.__version__}')
print(f'xgboost: {xgb.__version__}')
print(f'shap: {shap.__version__}')
print('\nAll imports successful!')
# Out:
# pandas: 3.0.1
# numpy: 2.4.2
# xgboost: 3.2.0
# shap: 0.50.0
#
# All imports successful!

# %%
import sys, os                                                        
sys.path.insert(0, r"C:\Users\domdd\Documents\GitHub\aura\modeling\src")                     
import data.loaders as loaders                                        
                                                                    
print("cwd:", os.getcwd())                                            
print("file:", loaders.__file__)                                      
print("PROJECT_ROOT:", loaders.PROJECT_ROOT)                          
print("DATA_DIR:", loaders.DATA_DIR)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       6 # Change to the correct directory
#       7 os.chdir('../')
# ----> 9 from data.loaders import load_core_matrix
#      10 df = load_core_matrix()
#      11 print(f'Data loaded: {len(df):,} patients')
#
# ModuleNotFoundError: No module named 'data.loaders'
